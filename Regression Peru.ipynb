# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'alldatasets.xlsx',sheet_name='Peru')

# %%
df.head()
# Out:
#     childid country      height  stunting_2cat  EDUYRS2   z_score  timeschool  \
# 0  PE018001    Peru  154.000000            0.0     12.0 -0.239376         5.0
# 1  PE018002    Peru  163.000000            0.0     15.5 -0.244915        10.0
# 2  PE018004    Peru  157.000000            0.0      7.0 -0.143035        15.0
# 3  PE018005    Peru  156.500000            0.0      7.0  0.375651        30.0
# 4  PE018006    Peru  160.100006            0.0     12.0  0.435034        15.0
#
#    agegapr1  momeduyrsr1  chsexr1  agemonr1  hhsizer1  wi_newr1  job_cat  \
# 0       NaN          7.0        0        98         5  0.558814        5
# 1       4.0         12.0        1        94         4  0.615497        2
# 2       NaN         12.0        0        90         5  0.428947        5
# 3       0.0          9.0        0        91         4  0.337719        5
# 4      10.0         12.0        0        93         4  0.537803        5
#
#    pvt_sector  earn    earn_usd
# 0           1   700  207.403626
# 1           1     0    0.000000
# 2           1   400  118.516357
# 3           1   700  207.403626
# 4           1  1400  414.807251

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 469 entries, 0 to 468
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   childid        469 non-null    object
#  1   country        469 non-null    object
#  2   height         469 non-null    float64
#  3   stunting_2cat  466 non-null    float64
#  4   EDUYRS2        469 non-null    float64
#  5   z_score        455 non-null    float64
#  6   timeschool     460 non-null    float64
#  7   agegapr1       360 non-null    float64
#  8   momeduyrsr1    444 non-null    float64
#  9   chsexr1        469 non-null    int64
#  10  agemonr1       469 non-null    int64
#  11  hhsizer1       469 non-null    int64
#  12  wi_newr1       465 non-null    float64
#  13  job_cat        469 non-null    int64
#  14  pvt_sector     469 non-null    int64
#  15  earn           469 non-null    int64
#  16  earn_usd       469 non-null    float64
# dtypes: float64(9), int64(6), object(2)
# memory usage: 62.4+ KB

# %%
import statsmodels.api as sm

# %% [markdown]
# # cognition

# %%
#cognition

X = df["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df["z_score"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                z_score   R-squared:                       0.054
# Model:                            OLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     25.56
# Date:                Tue, 11 May 2021   Prob (F-statistic):           6.24e-07
# Time:                        15:56:08   Log-Likelihood:                -616.49
# No. Observations:                 452   AIC:                             1237.
# Df Residuals:                     450   BIC:                             1245.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.1645      0.052      3.145      0.002       0.062       0.267
# stunting_2cat    -0.5069      0.100     -5.056      0.000      -0.704      -0.310
# ==============================================================================
# Omnibus:                       46.606   Durbin-Watson:                   1.578
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.831
# Skew:                          -0.663   Prob(JB):                     2.07e-17
# Kurtosis:                       4.523   Cond. No.                         2.45
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Height

# %%
#Height

X = df["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df["height"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 height   R-squared:                       0.116
# Model:                            OLS   Adj. R-squared:                  0.114
# Method:                 Least Squares   F-statistic:                     60.89
# Date:                Tue, 11 May 2021   Prob (F-statistic):           4.04e-14
# Time:                        15:56:08   Log-Likelihood:                -1614.7
# No. Observations:                 466   AIC:                             3233.
# Df Residuals:                     464   BIC:                             3242.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           161.6150      0.420    384.844      0.000     160.790     162.440
# stunting_2cat    -6.3270      0.811     -7.803      0.000      -7.920      -4.734
# ==============================================================================
# Omnibus:                        5.097   Durbin-Watson:                   2.042
# Prob(Omnibus):                  0.078   Jarque-Bera (JB):                3.880
# Skew:                           0.101   Prob(JB):                        0.144
# Kurtosis:                       2.601   Cond. No.                         2.46
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # education

# %%
#education

X = df["stunting_2cat"] ## X usually means our input variables (or independent variables)
y = df["EDUYRS2"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                EDUYRS2   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.7412
# Date:                Tue, 11 May 2021   Prob (F-statistic):              0.390
# Time:                        15:56:08   Log-Likelihood:                -1103.1
# No. Observations:                 466   AIC:                             2210.
# Df Residuals:                     464   BIC:                             2219.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            11.7889      0.140     84.156      0.000      11.514      12.064
# stunting_2cat    -0.2329      0.270     -0.861      0.390      -0.764       0.299
# ==============================================================================
# Omnibus:                       36.678   Durbin-Watson:                   1.928
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.474
# Skew:                          -0.669   Prob(JB):                     2.20e-10
# Kurtosis:                       3.708   Cond. No.                         2.46
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # cognition covariates

# %%
df.columns
# Out:
# Index(['childid', 'country', 'height', 'stunting_2cat', 'EDUYRS2', 'z_score',
#        'timeschool', 'agegapr1', 'momeduyrsr1', 'chsexr1', 'agemonr1',
#        'hhsizer1', 'wi_newr1', 'job_cat', 'pvt_sector', 'earn', 'earn_usd'],
#       dtype='object')

# %%
X = df[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df["z_score"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                z_score   R-squared:                       0.358
# Model:                            OLS   Adj. R-squared:                  0.344
# Method:                 Least Squares   F-statistic:                     26.09
# Date:                Tue, 11 May 2021   Prob (F-statistic):           2.50e-28
# Time:                        15:56:08   Log-Likelihood:                -403.27
# No. Observations:                 336   AIC:                             822.5
# Df Residuals:                     328   BIC:                             853.1
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -2.1680      1.011     -2.143      0.033      -4.158      -0.178
# stunting_2cat    -0.1163      0.105     -1.104      0.271      -0.324       0.091
# agemonr1          0.0162      0.010      1.545      0.123      -0.004       0.037
# chsexr1          -0.0147      0.091     -0.162      0.871      -0.193       0.163
# agegapr1          0.0092      0.011      0.858      0.392      -0.012       0.030
# momeduyrsr1       0.0572      0.013      4.423      0.000       0.032       0.083
# hhsizer1         -0.0903      0.026     -3.505      0.001      -0.141      -0.040
# wi_newr1          1.4724      0.236      6.241      0.000       1.008       1.937
# ==============================================================================
# Omnibus:                       22.410   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.331
# Skew:                          -0.449   Prob(JB):                     2.13e-08
# Kurtosis:                       4.310   Cond. No.                     2.19e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # Height covariates

# %%
X = df[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df["height"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 height   R-squared:                       0.620
# Model:                            OLS   Adj. R-squared:                  0.612
# Method:                 Least Squares   F-statistic:                     79.10
# Date:                Tue, 11 May 2021   Prob (F-statistic):           1.88e-67
# Time:                        15:56:08   Log-Likelihood:                -1042.7
# No. Observations:                 347   AIC:                             2101.
# Df Residuals:                     339   BIC:                             2132.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           147.9017      6.036     24.504      0.000     136.029     159.774
# stunting_2cat    -6.1131      0.632     -9.666      0.000      -7.357      -4.869
# agemonr1          0.0727      0.063      1.163      0.246      -0.050       0.196
# chsexr1          11.5050      0.541     21.270      0.000      10.441      12.569
# agegapr1          0.0183      0.065      0.284      0.777      -0.109       0.145
# momeduyrsr1       0.0296      0.078      0.381      0.704      -0.123       0.182
# hhsizer1         -0.0957      0.154     -0.623      0.533      -0.398       0.206
# wi_newr1          1.8945      1.418      1.336      0.182      -0.895       4.684
# ==============================================================================
# Omnibus:                       18.008   Durbin-Watson:                   1.773
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.990
# Skew:                           0.456   Prob(JB):                     1.68e-05
# Kurtosis:                       3.830   Cond. No.                     2.18e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.18e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # education covariates

# %%
X = df[["stunting_2cat",'agemonr1','chsexr1','agegapr1','momeduyrsr1','hhsizer1','wi_newr1']] ## X usually means our input variables (or independent variables)
y = df["EDUYRS2"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model
# Note the difference in argument order
model = sm.OLS(y, X,missing='drop').fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                EDUYRS2   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     4.823
# Date:                Tue, 11 May 2021   Prob (F-statistic):           3.39e-05
# Time:                        15:56:08   Log-Likelihood:                -800.38
# No. Observations:                 347   AIC:                             1617.
# Df Residuals:                     339   BIC:                             1648.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            10.6494      3.003      3.547      0.000       4.743      16.556
# stunting_2cat     0.1738      0.315      0.552      0.581      -0.445       0.793
# agemonr1          0.0099      0.031      0.317      0.752      -0.051       0.071
# chsexr1          -0.7043      0.269     -2.617      0.009      -1.234      -0.175
# agegapr1         -0.0260      0.032     -0.807      0.420      -0.089       0.037
# momeduyrsr1       0.0359      0.039      0.929      0.354      -0.040       0.112
# hhsizer1         -0.1176      0.076     -1.540      0.125      -0.268       0.033
# wi_newr1          2.2316      0.706      3.163      0.002       0.844       3.619
# ==============================================================================
# Omnibus:                       11.899   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.283
# Skew:                          -0.457   Prob(JB):                      0.00215
# Kurtosis:                       3.115   Cond. No.                     2.18e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.18e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
